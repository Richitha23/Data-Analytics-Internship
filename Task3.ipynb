# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cleaned.csv")

# %%
df.hist(bins=10, figsize=(10, 8), grid=False)

# Customize the overall plot
plt.suptitle('Histograms of Each Numerical Column', fontsize=16)
plt.xlabel('Value')
plt.ylabel('Frequency')

# Display the plot
plt.show()
